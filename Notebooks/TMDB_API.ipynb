# %%
# Importing libraries 
import os 
import pandas as pd 
import requests

from dotenv import load_dotenv

# %%
path1 = "../ml-latest-small/ratings.csv"
path2 = "../ml-latest-small/movies.csv"
path3 = "../ml-latest-small/links.csv"

# %%
movies_df = pd.read_csv(path2)
movies_df.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
links_df =  pd.read_csv(path3)

links_df.head(10)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
# 5        6  113277    949.0
# 6        7  114319  11860.0
# 7        8  112302  45325.0
# 8        9  114576   9091.0
# 9       10  113189    710.0

# %% [markdown]
# # Get a list of all the tmbdID

# %%
# Check links_df info
links_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   imdbId   9742 non-null   int64
#  2   tmdbId   9734 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 228.5 KB

# %%
# Delete row with null values
links_df = links_df.dropna()

# %%
# Convert float to int
links_list = links_df["tmdbId"].astype(int)

# %%
links_list.head()
links_list[0]
# Out:
# 862

# %%
import pprint

# %%
# Set up API call for recommendation of the first 10 movies in links_df
import requests

url = "https://api.themoviedb.org/3/movie/862/recommendations?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzZTdjNTZkZTFkNjQxZWIyOGVhODRiNWRkODgzOTUxMCIsInN1YiI6IjY1Y2IyNzRmOGMzMTU5MDE3YzM5MGFlNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.i4FruSg4IDDl--CWmoNT3SUKtiqCgZm4O54CFZS2uzs"
}

response = requests.get(url, headers=headers).json()

print(response['results'][1])
# Out:
# {'adult': False, 'backdrop_path': '/uAfhsySkr1UzQg1zdg3dZQRz9Fd.jpg', 'id': 10193, 'title': 'Toy Story 3', 'original_language': 'en', 'original_title': 'Toy Story 3', 'overview': "Woody, Buzz, and the rest of Andy's toys haven't been played with in years. With Andy about to go to college, the gang find themselves accidentally left at a nefarious day care center. The toys must band together to escape and return home to Andy.", 'poster_path': '/AbbXspMOwdvwWZgVN0nabZq03Ec.jpg', 'media_type': 'movie', 'genre_ids': [16, 10751, 35], 'popularity': 72.753, 'release_date': '2010-06-16', 'video': False, 'vote_average': 7.795, 'vote_count': 14060}

# %%
movie_titles = []
movie_id = []
movie_plot = []
movie_poster = []
movie_genre = []
# Get recommendations for the first 10 movies from the api 
for i in range(0,50):
    movie_tmdbid = links_list[i]
    
    #Set up url 
    url = "https://api.themoviedb.org/3/movie/" + str(movie_tmdbid) + "/recommendations?language=en-US&page=1"
    
    #Set up headers -- To be moved into .env for security purposes 
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzZTdjNTZkZTFkNjQxZWIyOGVhODRiNWRkODgzOTUxMCIsInN1YiI6IjY1Y2IyNzRmOGMzMTU5MDE3YzM5MGFlNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.i4FruSg4IDDl--CWmoNT3SUKtiqCgZm4O54CFZS2uzs"
    }
    
    response = requests.get(url, headers=headers).json()
    for j in range(0,10):
        movie_titles.append(response['results'][j]['title'])
        movie_id.append(response['results'][j]['id'])
        movie_plot.append(response['results'][j]['overview'])
        movie_poster.append(response['results'][j]['poster_path'])
        movie_genre.append(response['results'][j]['genre_ids'])

# %%
for i in range(0,10):
    movie_tmdbid = links_list[i]
    
    #Set up url 
    url = "https://api.themoviedb.org/3/movie/" + str(movie_tmdbid) + "?language=en-US"
    

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzZTdjNTZkZTFkNjQxZWIyOGVhODRiNWRkODgzOTUxMCIsInN1YiI6IjY1Y2IyNzRmOGMzMTU5MDE3YzM5MGFlNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.i4FruSg4IDDl--CWmoNT3SUKtiqCgZm4O54CFZS2uzs"
    }

    response = requests.get(url, headers=headers).json()
#     print(response)
    movie_titles.append(response['title'])
    movie_id.append(response['id'])
    movie_plot.append(response['overview'])
    movie_poster.append(response['poster_path'])
    movie_genre.append(response['genres'][0]['id'])

# %%
test = pd.DataFrame({"id":movie_id,"Title":movie_titles,"Genre":movie_genre,"Plot":movie_plot,"Poster":movie_poster})

# %%
test.head()
# Out:
#       id           Title                    Genre  \
# 0    863     Toy Story 2          [16, 35, 10751]
# 1  10193     Toy Story 3          [16, 10751, 35]
# 2   9487    A Bug's Life  [12, 16, 35, 14, 10751]
# 3   8587   The Lion King          [10751, 16, 18]
# 4    585  Monsters, Inc.          [16, 35, 10751]
#
#                                                 Plot  \
# 0  Andy heads off to Cowboy Camp, leaving his toy...
# 1  Woody, Buzz, and the rest of Andy's toys haven...
# 2  On behalf of "oppressed bugs everywhere," an i...
# 3  A young lion prince is cast out of his pride b...
# 4  Lovable Sulley and his wisecracking sidekick M...
#
#                              Poster
# 0  /2MFIhZAW0CVlEQrFyqwa4U6zqJP.jpg
# 1  /AbbXspMOwdvwWZgVN0nabZq03Ec.jpg
# 2  /Ah3J9OJVc2CNCuH2zMydXy9fmIC.jpg
# 3  /sKCr78MXSLixwmZ8DyJLrpMsd15.jpg
# 4  /wFSpyMsp7H0ttERbxY7Trlv8xry.jpg

# %%
len(test)
# Out:
# 510

# %%
test["id"].duplicated().any()
# Out:
# True

# %%
test = test.drop_duplicates(subset = ["id"])

# %%
len(test)
# Out:
# 419

# %%
test.head(50)
# Out:
#         id                           Title                    Genre  \
# 0      863                     Toy Story 2          [16, 35, 10751]
# 1    10193                     Toy Story 3          [16, 10751, 35]
# 2     9487                    A Bug's Life  [12, 16, 35, 14, 10751]
# 3     8587                   The Lion King          [10751, 16, 18]
# 4      585                  Monsters, Inc.          [16, 35, 10751]
# 5     9806                 The Incredibles      [28, 12, 16, 10751]
# 6    14160                              Up      [16, 35, 10751, 12]
# 7       12                    Finding Nemo              [16, 10751]
# 8      807                           Se7en           [80, 9648, 53]
# 9    10681                          WALL·E         [16, 10751, 878]
# 10  353486  Jumanji: Welcome to the Jungle             [12, 35, 14]
# 11    1593             Night at the Museum  [28, 12, 35, 10751, 14]
# 12    6795      Zathura: A Space Adventure         [878, 12, 10751]
# ...

# %%
outname = 'tmdb_movies_list'

outdir = '../Resources'
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)    

test.to_csv(fullname, index= False)
