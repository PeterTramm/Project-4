# %% [markdown]
# # Create a Movie Reccommendation Model

# %%
import pandas as pd 
import os 
import numpy as np

# %%
# Read in files 
path1 = "../Resources/movie_metadata"
path2 = "../Resources/user_ratings"

# %%
metadata = pd.read_csv(path1)
user_ratings = pd.read_csv(path2)

# %%
metadata.head()
# Out:
#    MovieID     ImdbID                               Title  Rated  \
# 0        1  tt0114709                    Toy Story (1995)      G
# 1        2  tt0113497                      Jumanji (1995)     PG
# 2        3  tt0113228             Grumpier Old Men (1995)  PG-13
# 3        4  tt0114885            Waiting to Exhale (1995)      R
# 4        5  tt0113041  Father of the Bride Part II (1995)     PG
#
#                      Genre_imdb  \
# 0  Animation, Adventure, Comedy
# 1     Adventure, Comedy, Family
# 2               Comedy, Romance
# 3        Comedy, Drama, Romance
# 4       Comedy, Family, Romance
#
#                                                 Plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with his daugh...
#
#                                               Poster
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...

# %%
user_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

def matrix_creation(element):
    
    #Replace NaN with an empty string
    metadata[element] = metadata[element].fillna('')

    #Construct the required TF-IDF matrix by fitting and transforming the data
    tfidf_matrix = tfidf.fit_transform(metadata[element])
    
    return tfidf_matrix

# %%
matrix_creation("Plot")
# Out:
# <200x1846 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2782 stored elements in Compressed Sparse Row format>

# %%
tfidf_matrix = tfidf.fit_transform(metadata["Plot"])

# %%
# Create an serie of just title and index 

indices = pd.Series(metadata.index, index = metadata["Title"])

indices.head()
# Out:
# Title
# Toy Story (1995)                      0
# Jumanji (1995)                        1
# Grumpier Old Men (1995)               2
# Waiting to Exhale (1995)              3
# Father of the Bride Part II (1995)    4
# dtype: int64

# %%
from sklearn.metrics.pairwise import linear_kernel
from sklearn.metrics import ndcg_score

cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(title, element, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    tfidf_matrix = matrix_creation(element)
    
    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    test = pd.DataFrame({"Title":metadata['Title'].iloc[movie_indices], "sim_score": sim_scores, "Genres":metadata['Genre_imdb'].iloc[movie_indices], "Plot":metadata['Plot'].iloc[movie_indices]}).reset_index(drop=False)
    
    # Calculate relevance score 
    movie_title_genre = list(metadata.loc[metadata["Title"] == title]["Genre_imdb"])[0].split(",")
    movie_title_genre_list = [i.strip() for i in movie_title_genre]

    relevance_score = []
    
    # Loop through each row in the reccomendation and calculate relevance score 
    for i in range(0,len(test)):
        
        genre_list = [i.strip() for i in test["Genres"][i].split(",")]
#         print(genre_list)
        relevance_score.append(len([i.strip() for i in genre_list if i.strip() in movie_title_genre_list]))
    
    # Add relevance score into dataframe
    test["Relevance Score"] = relevance_score
    
    
    # Calculate nDCG scores 
    ideal_score = test["Relevance Score"].sort_values(ascending=False)
    
    
    ideal_score = np.asarray([ideal_score])
    relevance_score = np.asarray([relevance_score])
    
    test_ndcg = ndcg_score(ideal_score, relevance_score)
    ideal_ndcg = ndcg_score(ideal_score, ideal_score)
    
    score_ndcg = test_ndcg/ideal_ndcg
    print("Relevance nDCG:" + str(test_ndcg))
    print("Ideal nDCG:" + str(ideal_ndcg))
    print("nDCG score:" + str(score_ndcg))
    
    
#     print(relevance_list)
    # Return the top 10 most similar movies
    return test

# %%
# Reccommendation based on genre alone
get_recommendations('Toy Story (1995)', "Genre_imdb")
# Out:
# Relevance nDCG:0.9765640703216261
# Ideal nDCG:1.0
# nDCG score:0.9765640703216261
#    index                                  Title                   sim_score  \
# 0     12                           Balto (1995)    (12, 0.9213163608368214)
# 1     44                      Pocahontas (1995)    (44, 0.9213163608368214)
# 2      7                    Tom and Huck (1995)     (7, 0.5243685970643143)
# 3     18  Ace Ventura: When Nature Calls (1995)   (18, 0.46169969788809245)
# 4    180                     Bushwhacked (1995)  (180, 0.46169969788809245)
# 5     14                Cutthroat Island (1995)    (14, 0.4442098870340997)
# 6     95          Muppet Treasure Island (1996)    (95, 0.4442098870340997)
# 7     77                    White Squall (1996)   (77, 0.42728755949695035)
# 8    187                       Cure, The (1995)  (187, 0.42728755949695035)
# 9      1                         Jumanji (1995)     (1, 0.3926475198283904)
#
#                         Genres  \
# 0  Animation, Adventure, Drama
# 1  Animation, Adventure, Drama
# 2     Adventure, Comedy, Drama
# 3     Adventure, Comedy, Crime
# 4     Adventure, Comedy, Crime
# 5    Action, Adventure, Comedy
# 6    Action, Adventure, Comedy
# 7             Adventure, Drama
# 8             Adventure, Drama
# 9    Adventure, Comedy, Family
#
#                                                 Plot  Relevance Score
# 0  An outcast Husky risks his life with other sle...                2
# 1  An English soldier and the daughter of an Algo...                2
# 2  Two best friends witness a murder and embark o...                2
# 3  Ace Ventura, Pet Detective, returns from a spi...                2
# 4  Framed for murder and on the run from authorit...                2
# 5  A female pirate and her companion race against...                2
# 6  The Muppets set sail in search of treasure, wi...                2
# 7  Teenage boys discover discipline and camarader...                1
# 8  Erik, a loner, finds a friend in Dexter, an el...                1
# 9  When two kids find and play a magical board ga...                2

# %%
get_recommendations("Balto (1995)", "Genre_imdb")
# Out:
# Relevance nDCG:1.0
# Ideal nDCG:1.0
# nDCG score:1.0
#    index                                    Title                   sim_score  \
# 0     44                        Pocahontas (1995)                   (44, 1.0)
# 1      0                         Toy Story (1995)     (0, 0.9213163608368214)
# 2     77                      White Squall (1996)    (77, 0.5477307089075028)
# 3    187                         Cure, The (1995)   (187, 0.5477307089075028)
# 4      7                      Tom and Huck (1995)      (7, 0.474956865904372)
# 5    128                    Beyond Rangoon (1995)  (128, 0.41658302159445093)
# 6    140                      First Knight (1995)  (140, 0.41658302159445093)
# 7    124                           Rob Roy (1995)   (124, 0.3690247252956399)
# 8    119      Amazing Panda Adventure, The (1995)   (119, 0.3653627192161314)
# 9    141  Free Willy 2: The Adventure Home (1995)   (141, 0.3653627192161314)
#
#                          Genres  \
# 0   Animation, Adventure, Drama
# 1  Animation, Adventure, Comedy
# 2              Adventure, Drama
# 3              Adventure, Drama
# 4      Adventure, Comedy, Drama
# 5      Action, Adventure, Drama
# 6      Action, Adventure, Drama
# 7   Adventure, Biography, Drama
# 8      Adventure, Drama, Family
# 9      Adventure, Drama, Family
#
#                                                 Plot  Relevance Score
# 0  An English soldier and the daughter of an Algo...                3
# 1  A cowboy doll is profoundly threatened and jea...                2
# 2  Teenage boys discover discipline and camarader...                2
# 3  Erik, a loner, finds a friend in Dexter, an el...                2
# 4  Two best friends witness a murder and embark o...                2
# 5  Laura is trying to pick up the pieces of her l...                2
# 6  Lancelot falls in love with Guinevere, who is ...                2
# 7  In 1713 Scotland, Rob Roy MacGregor is wronged...                2
# 8  A young American boy visiting China helps his ...                2
# 9  Teenager Jesse becomes reunited with Willy two...                2

# %%
get_recommendations("Grumpier Old Men (1995)", "Genre_imdb")
# Out:
# Relevance nDCG:1.0
# Ideal nDCG:1.0
# nDCG score:1.0
#    index                           Title                  sim_score  \
# 0     35                 Clueless (1995)   (35, 0.9999999999999999)
# 1    103             If Lucy Fell (1996)  (103, 0.9999999999999999)
# 2    111           Pie in the Sky (1996)  (111, 0.9999999999999999)
# 3    114          Man of the Year (1995)  (114, 0.9999999999999999)
# 4    152                 Mallrats (1995)  (152, 0.9999999999999999)
# 5    157              Nine Months (1995)  (157, 0.9999999999999999)
# 6      3        Waiting to Exhale (1995)    (3, 0.9005667163400763)
# 7      6                  Sabrina (1995)    (6, 0.9005667163400763)
# 8     10  American President, The (1995)   (10, 0.9005667163400763)
# 9     26             Now and Then (1995)   (26, 0.9005667163400763)
#
#                    Genres                                               Plot  \
# 0         Comedy, Romance  Shallow, rich and socially successful Cher is ...
# 1         Comedy, Romance  Two NYC roommates have a pact to jump off Broo...
# 2         Comedy, Romance  A whimsical saga of a young man whose two life...
# 3         Comedy, Romance  Mockumentary look at Playgirl Magazine centerf...
# 4         Comedy, Romance  Both dumped by their girlfriends, two best fri...
# 5         Comedy, Romance  When he finds out his longtime girlfriend is p...
# 6  Comedy, Drama, Romance  Based on Terry McMillan's novel, this film fol...
# 7  Comedy, Drama, Romance  An ugly duckling having undergone a remarkable...
# 8  Comedy, Drama, Romance  A widowed U.S. President running for reelectio...
# 9  Comedy, Drama, Romance  Four 12-year-old girls grow up together during...
#
#    Relevance Score
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# 5                2
# 6                2
# 7                2
# 8                2
# 9                2

# %%
get_recommendations("Grumpier Old Men (1995)", "Plot")
# Out:
# Relevance nDCG:0.8494724404118942
# Ideal nDCG:1.0000000000000002
# nDCG score:0.849472440411894
#    index                                          Title  \
# 0     63                               Fair Game (1995)
# 1    138              Die Hard: With a Vengeance (1995)
# 2    107  Chungking Express (Chung Hing sam lam) (1994)
# 3    164                                   Smoke (1995)
# 4    106                               Boomerang (1992)
# 5     95                  Muppet Treasure Island (1996)
# 6     52              Postman, The (Postino, Il) (1994)
# 7     14                        Cutthroat Island (1995)
# 8    188                            Castle Freak (1995)
# 9     80                            Nick of Time (1995)
#
#                     sim_score                            Genres  \
# 0   (63, 0.12508614881494196)         Action, Romance, Thriller
# 1  (138, 0.12328996781006432)       Action, Adventure, Thriller
# 2   (107, 0.0986517631500813)              Comedy, Crime, Drama
# 3  (164, 0.08197148647421218)                     Comedy, Drama
# 4  (106, 0.08031721945709384)            Comedy, Drama, Romance
# 5   (95, 0.06532093460833328)         Action, Adventure, Comedy
# 6   (52, 0.06012315958628552)          Biography, Comedy, Drama
# 7  (14, 0.053752580899324894)         Action, Adventure, Comedy
# 8  (188, 0.05370901148803527)  Drama, Horror, Mystery, Thriller
# 9   (80, 0.05045847636800924)              Action, Crime, Drama
#
#                                                 Plot  Relevance Score
# 0  Max Kirkpatrick is a cop who protects Kate McQ...                1
# 1  John McClane and a Harlem store owner are targ...                0
# 2  Two melancholy Hong Kong policemen fall in lov...                1
# 3  A Brooklyn smoke shop is the center of neighbo...                1
# 4  A successful executive and womanizer finds his...                2
# 5  The Muppets set sail in search of treasure, wi...                1
# 6  A simple Italian postman learns to love poetry...                1
# 7  A female pirate and her companion race against...                1
# 8  A man struggles to save his family from the st...                0
# 9  An unimpressive, everyday man is forced into a...                0

# %%
# Recommendation based on plot alone
get_recommendations('Toy Story (1995)', "Plot")
# Out:
# Relevance nDCG:0.569920991215813
# Ideal nDCG:1.0
# nDCG score:0.569920991215813
#    index                                          Title  \
# 0     98                             Taxi Driver (1976)
# 1    119            Amazing Panda Adventure, The (1995)
# 2     88                               City Hall (1996)
# 3    120                 Basketball Diaries, The (1995)
# 4     47                        Mighty Aphrodite (1995)
# 5    107  Chungking Express (Chung Hing sam lam) (1994)
# 6     78                       Dunston Checks In (1996)
# 7    125                          Addiction, The (1995)
# 8     13                                   Nixon (1995)
# 9     17                              Four Rooms (1995)
#
#                     sim_score                     Genres  \
# 0   (98, 0.09573656083681767)               Crime, Drama
# 1  (119, 0.09536841495442028)   Adventure, Drama, Family
# 2   (88, 0.07589463421787788)      Crime, Drama, Mystery
# 3   (120, 0.0754287164278157)    Biography, Crime, Drama
# 4   (47, 0.07480595957787413)   Comedy, Fantasy, Romance
# 5  (107, 0.06685034375371283)       Comedy, Crime, Drama
# 6   (78, 0.06111872785166418)  Adventure, Comedy, Family
# 7  (125, 0.05529440056041926)              Drama, Horror
# 8  (13, 0.046434918636816126)  Biography, Drama, History
# 9  (17, 0.042932810426309635)                     Comedy
#
#                                                 Plot  Relevance Score
# 0  A mentally unstable veteran works as a nightti...                0
# 1  A young American boy visiting China helps his ...                1
# 2  The accidental shooting of a boy in New York l...                0
# 3  A teenager finds his dreams of becoming a bask...                0
# 4  When he discovers his adopted son is a genius,...                1
# 5  Two melancholy Hong Kong policemen fall in lov...                1
# 6  A young boy befriends a larcenous orangutan in...                2
# 7  A New York philosophy grad student turns into ...                0
# 8  A biographical story of former U.S. President ...                0
# 9  Four interlocking tales that take place in a f...                1

# %%
# Reccommendation based on rated type
get_recommendations('Toy Story (1995)', "Rated")
# Out:
# Relevance nDCG:0.8903266581268174
# Ideal nDCG:1.0000000000000002
# nDCG score:0.8903266581268172
#    index                               Title  sim_score  \
# 0      1                      Jumanji (1995)   (1, 0.0)
# 1      2             Grumpier Old Men (1995)   (2, 0.0)
# 2      3            Waiting to Exhale (1995)   (3, 0.0)
# 3      4  Father of the Bride Part II (1995)   (4, 0.0)
# 4      5                         Heat (1995)   (5, 0.0)
# 5      6                      Sabrina (1995)   (6, 0.0)
# 6      7                 Tom and Huck (1995)   (7, 0.0)
# 7      8                 Sudden Death (1995)   (8, 0.0)
# 8      9                    GoldenEye (1995)   (9, 0.0)
# 9     10      American President, The (1995)  (10, 0.0)
#
#                         Genres  \
# 0    Adventure, Comedy, Family
# 1              Comedy, Romance
# 2       Comedy, Drama, Romance
# 3      Comedy, Family, Romance
# 4         Action, Crime, Drama
# 5       Comedy, Drama, Romance
# 6     Adventure, Comedy, Drama
# 7      Action, Crime, Thriller
# 8  Action, Adventure, Thriller
# 9       Comedy, Drama, Romance
#
#                                                 Plot  Relevance Score
# 0  When two kids find and play a magical board ga...                2
# 1  John and Max resolve to save their beloved bai...                1
# 2  Based on Terry McMillan's novel, this film fol...                1
# 3  George Banks must deal not only with his daugh...                1
# 4  A group of high-end professional thieves start...                0
# 5  An ugly duckling having undergone a remarkable...                1
# 6  Two best friends witness a murder and embark o...                2
# 7  A former fireman takes on a group of terrorist...                0
# 8  Years after a friend and fellow 00 agent is ki...                1
# 9  A widowed U.S. President running for reelectio...                1

# %%
metadata["plot + genre"] = metadata["Genre_imdb"] + ' ' + metadata["Plot"]

metadata.head()
# Out:
#    MovieID     ImdbID                               Title  Rated  \
# 0        1  tt0114709                    Toy Story (1995)      G
# 1        2  tt0113497                      Jumanji (1995)     PG
# 2        3  tt0113228             Grumpier Old Men (1995)  PG-13
# 3        4  tt0114885            Waiting to Exhale (1995)      R
# 4        5  tt0113041  Father of the Bride Part II (1995)     PG
#
#                      Genre_imdb  \
# 0  Animation, Adventure, Comedy
# 1     Adventure, Comedy, Family
# 2               Comedy, Romance
# 3        Comedy, Drama, Romance
# 4       Comedy, Family, Romance
#
#                                                 Plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with his daugh...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...
#
#                                         plot + genre
# 0  Animation, Adventure, Comedy A cowboy doll is ...
# 1  Adventure, Comedy, Family When two kids find a...
# 2  Comedy, Romance John and Max resolve to save t...
# 3  Comedy, Drama, Romance Based on Terry McMillan...
# 4  Comedy, Family, Romance George Banks must deal...

# %%
get_recommendations('Toy Story (1995)','plot + genre')
# Out:
# Relevance nDCG:0.857219016476455
# Ideal nDCG:1.0000000000000002
# nDCG score:0.8572190164764548
#    index                                          Title  \
# 0    119            Amazing Panda Adventure, The (1995)
# 1     78                       Dunston Checks In (1996)
# 2     12                                   Balto (1995)
# 3     47                        Mighty Aphrodite (1995)
# 4    133                                   Congo (1995)
# 5     44                              Pocahontas (1995)
# 6    107  Chungking Express (Chung Hing sam lam) (1994)
# 7     88                               City Hall (1996)
# 8    120                 Basketball Diaries, The (1995)
# 9    109              NeverEnding Story III, The (1994)
#
#                     sim_score                       Genres  \
# 0  (119, 0.11013986953198283)     Adventure, Drama, Family
# 1   (78, 0.09900552455609749)    Adventure, Comedy, Family
# 2   (12, 0.08578522109002469)  Animation, Adventure, Drama
# 3   (47, 0.07999742483931899)     Comedy, Fantasy, Romance
# 4  (133, 0.07847372716370395)   Action, Adventure, Mystery
# 5   (44, 0.07809441979785128)  Animation, Adventure, Drama
# 6  (107, 0.07277938971871874)         Comedy, Crime, Drama
# 7   (88, 0.07219153132028869)        Crime, Drama, Mystery
# 8  (120, 0.07132701426112702)      Biography, Crime, Drama
# 9  (109, 0.07002001036307756)    Adventure, Comedy, Family
#
#                                                 Plot  Relevance Score
# 0  A young American boy visiting China helps his ...                1
# 1  A young boy befriends a larcenous orangutan in...                2
# 2  An outcast Husky risks his life with other sle...                2
# 3  When he discovers his adopted son is a genius,...                1
# 4  When an expedition to the African Congo ends i...                1
# 5  An English soldier and the daughter of an Algo...                2
# 6  Two melancholy Hong Kong policemen fall in lov...                1
# 7  The accidental shooting of a boy in New York l...                0
# 8  A teenager finds his dreams of becoming a bask...                0
# 9  A young boy must restore order when a group of...                2

# %%
# Calculate nDCG score 
from sklearn.metrics import ndcg_score

# %%
# Create a ideal relevance score list 
ideal_score = get_recommendations('Toy Story (1995)','plot + genre')["Relevance Score"].sort_values(ascending=False)

# Get the predicted relevance score 

relevance_score = get_recommendations('Toy Story (1995)','plot + genre')["Relevance Score"]
# Out:
# Relevance nDCG:0.857219016476455
# Ideal nDCG:1.0000000000000002
# nDCG score:0.8572190164764548
# Relevance nDCG:0.857219016476455
# Ideal nDCG:1.0000000000000002
# nDCG score:0.8572190164764548

# %%
ideal_score = np.asarray([ideal_score])
relevance_score = np.asarray([relevance_score])

# %%
ideal_score
# Out:
# array([[2, 2, 2, 2, 1, 1, 1, 1, 0, 0]])

# %%
relevance_score
# Out:
# array([[1, 2, 2, 1, 1, 2, 1, 0, 0, 2]])

# %%
true_relevance = np.asarray([[10, 0, 0, 1, 5]])
scores = np.asarray([[.1, .2, .3, 4, 70]])
ndcg_score(true_relevance, scores, k=3)
# Out:
# 0.4123818817534531

# %%
# Calculate nDCG score 
test_ndcg = ndcg_score(ideal_score, relevance_score)

# %%
# Calculate Ideal Score 
ideal_ndcg = ndcg_score(ideal_score, ideal_score)

# %%
print(test_ndcg/ideal_ndcg)
print(test_ndcg)
print(ideal_ndcg)
# Out:
# 0.8572190164764548
# 0.857219016476455
# 1.0000000000000002

# %% [markdown]
# # Using MLP CLASSIFIER

# %%
from sklearn.neighbors import NearestNeighbors

# %%
samples = matrix_creation("plot + genre")

neigh = NearestNeighbors(n_neighbors=10, radius=0.5)

neigh.fit(samples)
# Out:
# NearestNeighbors(n_neighbors=10, radius=0.5)

# %%
test_array = neigh.kneighbors(samples[0,:], return_distance=True)

test_array
# movie_ids_list = []
# movie_title_list = []
# movie_genre = []
# distance_list = []
# for i in test_array:
       
#     for j in i:
#         movie_ids_list.append(j)
#         movie_title_list.append(metadata["Title"][j])
#         movie_genre.append(metadata["Genre_imdb"][j])
# Out:
# (array([[0.        , 1.33406157, 1.34238182, 1.35219435, 1.3564679 ,
#          1.35759071, 1.35787008, 1.3617787 , 1.36221031, 1.36284481]]),
#  array([[  0, 119,  78,  12,  47, 133,  44, 107,  88, 120]]))

# %%
movie_indices = [i[0] for i in test_array]
movie_indices[1]

movie_index = []
distance_list = []
for i in range(0,len(movie_indices[1])):
    movie_index.append(movie_indices[1][i])
    distance_list.append(movie_indices[0][i])

# %%
test = pd.DataFrame({"Title":metadata['Title'].iloc[movie_index], "Genres":metadata['Genre_imdb'].iloc[movie_index], "Plot":metadata['Plot'].iloc[movie_index]}).reset_index(drop=False)

# %%
test.head()
# Out:
#    index                                Title                        Genres  \
# 0      0                     Toy Story (1995)  Animation, Adventure, Comedy
# 1    119  Amazing Panda Adventure, The (1995)      Adventure, Drama, Family
# 2     78             Dunston Checks In (1996)     Adventure, Comedy, Family
# 3     12                         Balto (1995)   Animation, Adventure, Drama
# 4     47              Mighty Aphrodite (1995)      Comedy, Fantasy, Romance
#
#                                                 Plot
# 0  A cowboy doll is profoundly threatened and jea...
# 1  A young American boy visiting China helps his ...
# 2  A young boy befriends a larcenous orangutan in...
# 3  An outcast Husky risks his life with other sle...
# 4  When he discovers his adopted son is a genius,...

# %%
def NN_get_reccommendation(title,clusters,):
    
    #Define model 
    neigh = NearestNeighbors(n_neighbors=clusters, radius=0.5)
    
    #Fit model to samples
    neigh.fit(samples)
    
    #Find the title index 
    idx = metadata.loc[metadata["Title"] == title].index
    
    #Find nearest neighbors of the title 
    test_array = neigh.kneighbors(samples[idx,:], return_distance=True)

    #Create list to store movie index and distance 
    movie_index = []
    distance_list = []
    
    # Loop through movie index 
    for i in range(0,len(movie_indices[1])):
        movie_index.append(movie_indices[1][i])
        distance_list.append(movie_indices[0][i])

# %%
metadata.loc[metadata["Title"] == "Toy Story (1995)"].index
# Out:
# Index([0], dtype='int64')

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(6, 4), random_state=1)
