# %% [markdown]
# # Create a Movie Reccommendation Model

# %%
import pandas as pd 
import os

# %%
# Read in files 
path1 = "../Resources/movie_metadata"
path2 = "../Resources/user_ratings"

# %%
metadata = pd.read_csv(path1)
user_ratings = pd.read_csv(path2)

# %%
metadata.head()
# Out:
#    MovieID     ImdbID                               Title  Rated  \
# 0        1  tt0114709                    Toy Story (1995)      G
# 1        2  tt0113497                      Jumanji (1995)     PG
# 2        3  tt0113228             Grumpier Old Men (1995)  PG-13
# 3        4  tt0114885            Waiting to Exhale (1995)      R
# 4        5  tt0113041  Father of the Bride Part II (1995)     PG
#
#                      Genre_imdb  \
# 0  Animation, Adventure, Comedy
# 1     Adventure, Comedy, Family
# 2               Comedy, Romance
# 3        Comedy, Drama, Romance
# 4       Comedy, Family, Romance
#
#                                                 Plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with his daugh...
#
#                                               Poster
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...

# %%
user_ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

def matrix_creation(element):
    #Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
#     tfidf = TfidfVectorizer(stop_words='english')

    #Replace NaN with an empty string
    metadata[element] = metadata[element].fillna('')

    #Construct the required TF-IDF matrix by fitting and transforming the data
    tfidf_matrix = tfidf.fit_transform(metadata[element])
    
    return tfidf_matrix

# %%
matrix_creation("Plot")
# Out:
# <200x1846 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2782 stored elements in Compressed Sparse Row format>

# %%
# Create an serie of just title and index 

indices = pd.Series(metadata.index, index = metadata["Title"])

indices.head()
# Out:
# Title
# Toy Story (1995)                      0
# Jumanji (1995)                        1
# Grumpier Old Men (1995)               2
# Waiting to Exhale (1995)              3
# Father of the Bride Part II (1995)    4
# dtype: int64

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
def get_recommendations(title, element, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the title
    idx = indices[title]
    
    tfidf_matrix = matrix_creation(element)
    
    # Compute the cosine similarity matrix
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]
    
    test = pd.DataFrame({"Title":metadata['Title'].iloc[movie_indices], "sim_score": sim_scores, "Genres":metadata['Genre_imdb'].iloc[movie_indices], "Plot":metadata['Plot'].iloc[movie_indices]}).reset_index(drop=False)
    
    # Calculate relevance score 
    movie_title_genre = list(metadata.loc[metadata["Title"] == title]["Genre_imdb"])[0].split(",")
    
    relevance_list = []
    
    # Loop through each row in the reccomendation and calculate relevance score 
    for i in range(0,len(test)):
        genre_list = [i.strip() for i in metadata["Genre_imdb"][i].split(",")]
        relevance_list.append(len([i.strip() for i in genre_list if i in movie_title_genre]))
    
    test["Relevance Score"] = relevance_list
    # Return the top 10 most similar movies
    print(movie_title_genre)
    return test

# %%
Toy_genre = list(metadata.loc[metadata["Title"] == "Toy Story (1995)"]["Genre_imdb"])[0].split(",")
Balto_genre = list(metadata.loc[metadata["Title"] == "Balto (1995)"]["Genre_imdb"])[0].split(",")

print(Toy_genre)
print(Balto_genre)
# Out:
# ['Animation', ' Adventure', ' Comedy']
# ['Animation', ' Adventure', ' Drama']

# %%
[i for i in metadata["Genre_imdb"][0].split(",")]
# Out:
# ['Animation', ' Adventure', ' Comedy']

# %%
list(metadata.loc[metadata["Title"] == "Toy Story (1995)"]["Genre_imdb"])[0].split(",")
# Out:
# ['Animation', ' Adventure', ' Comedy']

# %%
c = len([i.strip() for i in Balto_genre if i in Toy_genre])
c
# Out:
# 2

# %%
genre_list = [i for i in metadata["Genre_imdb"][0].split(",")]
movie_title_genre = list(metadata.loc[metadata["Title"] == "Toy Story (1995)"]["Genre_imdb"])[0].split(",")
print(genre_list)
print(movie_title_genre)
len([i.strip() for i in genre_list if i in movie_title_genre])
# Out:
# ['Animation', ' Adventure', ' Comedy']
# ['Animation', ' Adventure', ' Comedy']
# 3

# %%
# Reccommendation based on genre alone
get_recommendations('Toy Story (1995)', "Genre_imdb")
# Out:
# ['Animation', ' Adventure', ' Comedy']
#    index                                  Title                   sim_score  \
# 0     12                           Balto (1995)    (12, 0.9213163608368214)
# 1     44                      Pocahontas (1995)    (44, 0.9213163608368214)
# 2      7                    Tom and Huck (1995)     (7, 0.5243685970643143)
# 3     18  Ace Ventura: When Nature Calls (1995)   (18, 0.46169969788809245)
# 4    180                     Bushwhacked (1995)  (180, 0.46169969788809245)
# 5     14                Cutthroat Island (1995)    (14, 0.4442098870340997)
# 6     95          Muppet Treasure Island (1996)    (95, 0.4442098870340997)
# 7     77                    White Squall (1996)   (77, 0.42728755949695035)
# 8    187                       Cure, The (1995)  (187, 0.42728755949695035)
# 9      1                         Jumanji (1995)     (1, 0.3926475198283904)
#
#                         Genres  \
# 0  Animation, Adventure, Drama
# 1  Animation, Adventure, Drama
# 2     Adventure, Comedy, Drama
# 3     Adventure, Comedy, Crime
# 4     Adventure, Comedy, Crime
# 5    Action, Adventure, Comedy
# 6    Action, Adventure, Comedy
# 7             Adventure, Drama
# 8             Adventure, Drama
# 9    Adventure, Comedy, Family
#
#                                                 Plot  Relevance Score
# 0  An outcast Husky risks his life with other sle...                1
# 1  An English soldier and the daughter of an Algo...                0
# 2  Two best friends witness a murder and embark o...                0
# 3  Ace Ventura, Pet Detective, returns from a spi...                0
# 4  Framed for murder and on the run from authorit...                0
# 5  A female pirate and her companion race against...                0
# 6  The Muppets set sail in search of treasure, wi...                0
# 7  Teenage boys discover discipline and camarader...                0
# 8  Erik, a loner, finds a friend in Dexter, an el...                0
# 9  When two kids find and play a magical board ga...                0

# %%
get_recommendations("Balto (1995)", "Genre_imdb")
# Out:
#                                        Title                   sim_score  \
# 44                         Pocahontas (1995)                   (44, 1.0)
# 0                           Toy Story (1995)     (0, 0.9213163608368214)
# 77                       White Squall (1996)    (77, 0.5477307089075028)
# 187                         Cure, The (1995)   (187, 0.5477307089075028)
# 7                        Tom and Huck (1995)      (7, 0.474956865904372)
# 128                    Beyond Rangoon (1995)  (128, 0.41658302159445093)
# 140                      First Knight (1995)  (140, 0.41658302159445093)
# 124                           Rob Roy (1995)   (124, 0.3690247252956399)
# 119      Amazing Panda Adventure, The (1995)   (119, 0.3653627192161314)
# 141  Free Willy 2: The Adventure Home (1995)   (141, 0.3653627192161314)
#
#                            Genres  \
# 44    Animation, Adventure, Drama
# 0    Animation, Adventure, Comedy
# 77               Adventure, Drama
# 187              Adventure, Drama
# 7        Adventure, Comedy, Drama
# 128      Action, Adventure, Drama
# 140      Action, Adventure, Drama
# 124   Adventure, Biography, Drama
# 119      Adventure, Drama, Family
# 141      Adventure, Drama, Family
#
#                                                   Plot
# 44   An English soldier and the daughter of an Algo...
# 0    A cowboy doll is profoundly threatened and jea...
# 77   Teenage boys discover discipline and camarader...
# 187  Erik, a loner, finds a friend in Dexter, an el...
# 7    Two best friends witness a murder and embark o...
# 128  Laura is trying to pick up the pieces of her l...
# 140  Lancelot falls in love with Guinevere, who is ...
# 124  In 1713 Scotland, Rob Roy MacGregor is wronged...
# 119  A young American boy visiting China helps his ...
# 141  Teenager Jesse becomes reunited with Willy two...

# %%
get_recommendations("Grumpier Old Men (1995)", "Genre_imdb")
# Out:
#                               Title                  sim_score  \
# 35                  Clueless (1995)   (35, 0.9999999999999999)
# 103             If Lucy Fell (1996)  (103, 0.9999999999999999)
# 111           Pie in the Sky (1996)  (111, 0.9999999999999999)
# 114          Man of the Year (1995)  (114, 0.9999999999999999)
# 152                 Mallrats (1995)  (152, 0.9999999999999999)
# 157              Nine Months (1995)  (157, 0.9999999999999999)
# 3          Waiting to Exhale (1995)    (3, 0.9005667163400763)
# 6                    Sabrina (1995)    (6, 0.9005667163400763)
# 10   American President, The (1995)   (10, 0.9005667163400763)
# 26              Now and Then (1995)   (26, 0.9005667163400763)
#
#                      Genres                                               Plot
# 35          Comedy, Romance  Shallow, rich and socially successful Cher is ...
# 103         Comedy, Romance  Two NYC roommates have a pact to jump off Broo...
# 111         Comedy, Romance  A whimsical saga of a young man whose two life...
# 114         Comedy, Romance  Mockumentary look at Playgirl Magazine centerf...
# 152         Comedy, Romance  Both dumped by their girlfriends, two best fri...
# 157         Comedy, Romance  When he finds out his longtime girlfriend is p...
# 3    Comedy, Drama, Romance  Based on Terry McMillan's novel, this film fol...
# 6    Comedy, Drama, Romance  An ugly duckling having undergone a remarkable...
# 10   Comedy, Drama, Romance  A widowed U.S. President running for reelectio...
# 26   Comedy, Drama, Romance  Four 12-year-old girls grow up together during...

# %%
get_recommendations("Grumpier Old Men (1995)", "Plot")
# Out:
#                                              Title  \
# 63                                Fair Game (1995)
# 138              Die Hard: With a Vengeance (1995)
# 107  Chungking Express (Chung Hing sam lam) (1994)
# 164                                   Smoke (1995)
# 106                               Boomerang (1992)
# 95                   Muppet Treasure Island (1996)
# 52               Postman, The (Postino, Il) (1994)
# 14                         Cutthroat Island (1995)
# 188                            Castle Freak (1995)
# 80                             Nick of Time (1995)
#
#                       sim_score                            Genres  \
# 63    (63, 0.12508614881494196)         Action, Romance, Thriller
# 138  (138, 0.12328996781006432)       Action, Adventure, Thriller
# 107   (107, 0.0986517631500813)              Comedy, Crime, Drama
# 164  (164, 0.08197148647421218)                     Comedy, Drama
# 106  (106, 0.08031721945709384)            Comedy, Drama, Romance
# 95    (95, 0.06532093460833328)         Action, Adventure, Comedy
# 52    (52, 0.06012315958628552)          Biography, Comedy, Drama
# 14   (14, 0.053752580899324894)         Action, Adventure, Comedy
# 188  (188, 0.05370901148803527)  Drama, Horror, Mystery, Thriller
# 80    (80, 0.05045847636800924)              Action, Crime, Drama
#
#                                                   Plot
# 63   Max Kirkpatrick is a cop who protects Kate McQ...
# 138  John McClane and a Harlem store owner are targ...
# 107  Two melancholy Hong Kong policemen fall in lov...
# 164  A Brooklyn smoke shop is the center of neighbo...
# 106  A successful executive and womanizer finds his...
# 95   The Muppets set sail in search of treasure, wi...
# 52   A simple Italian postman learns to love poetry...
# 14   A female pirate and her companion race against...
# 188  A man struggles to save his family from the st...
# 80   An unimpressive, everyday man is forced into a...

# %%
# Determing precision at @ k

# %%
# Recommendation based on plot alone
get_recommendations('Toy Story (1995)', "Plot")
# Out:
#                                              Title  \
# 98                              Taxi Driver (1976)
# 119            Amazing Panda Adventure, The (1995)
# 88                                City Hall (1996)
# 120                 Basketball Diaries, The (1995)
# 47                         Mighty Aphrodite (1995)
# 107  Chungking Express (Chung Hing sam lam) (1994)
# 78                        Dunston Checks In (1996)
# 125                          Addiction, The (1995)
# 13                                    Nixon (1995)
# 17                               Four Rooms (1995)
#
#                       sim_score                     Genres  \
# 98    (98, 0.09573656083681767)               Crime, Drama
# 119  (119, 0.09536841495442028)   Adventure, Drama, Family
# 88    (88, 0.07589463421787788)      Crime, Drama, Mystery
# 120   (120, 0.0754287164278157)    Biography, Crime, Drama
# 47    (47, 0.07480595957787413)   Comedy, Fantasy, Romance
# 107  (107, 0.06685034375371283)       Comedy, Crime, Drama
# 78    (78, 0.06111872785166418)  Adventure, Comedy, Family
# 125  (125, 0.05529440056041926)              Drama, Horror
# 13   (13, 0.046434918636816126)  Biography, Drama, History
# 17   (17, 0.042932810426309635)                     Comedy
#
#                                                   Plot
# 98   A mentally unstable veteran works as a nightti...
# 119  A young American boy visiting China helps his ...
# 88   The accidental shooting of a boy in New York l...
# 120  A teenager finds his dreams of becoming a bask...
# 47   When he discovers his adopted son is a genius,...
# 107  Two melancholy Hong Kong policemen fall in lov...
# 78   A young boy befriends a larcenous orangutan in...
# 125  A New York philosophy grad student turns into ...
# 13   A biographical story of former U.S. President ...
# 17   Four interlocking tales that take place in a f...

# %%
# Reccommendation based on rated type
get_recommendations('Toy Story (1995)', "Rated")
# Out:
#                                  Title  sim_score  \
# 1                       Jumanji (1995)   (1, 0.0)
# 2              Grumpier Old Men (1995)   (2, 0.0)
# 3             Waiting to Exhale (1995)   (3, 0.0)
# 4   Father of the Bride Part II (1995)   (4, 0.0)
# 5                          Heat (1995)   (5, 0.0)
# 6                       Sabrina (1995)   (6, 0.0)
# 7                  Tom and Huck (1995)   (7, 0.0)
# 8                  Sudden Death (1995)   (8, 0.0)
# 9                     GoldenEye (1995)   (9, 0.0)
# 10      American President, The (1995)  (10, 0.0)
#
#                          Genres  \
# 1     Adventure, Comedy, Family
# 2               Comedy, Romance
# 3        Comedy, Drama, Romance
# 4       Comedy, Family, Romance
# 5          Action, Crime, Drama
# 6        Comedy, Drama, Romance
# 7      Adventure, Comedy, Drama
# 8       Action, Crime, Thriller
# 9   Action, Adventure, Thriller
# 10       Comedy, Drama, Romance
#
#                                                  Plot
# 1   When two kids find and play a magical board ga...
# 2   John and Max resolve to save their beloved bai...
# 3   Based on Terry McMillan's novel, this film fol...
# 4   George Banks must deal not only with his daugh...
# 5   A group of high-end professional thieves start...
# 6   An ugly duckling having undergone a remarkable...
# 7   Two best friends witness a murder and embark o...
# 8   A former fireman takes on a group of terrorist...
# 9   Years after a friend and fellow 00 agent is ki...
# 10  A widowed U.S. President running for reelectio...

# %%
metadata["plot + genre"] = metadata["Genre_imdb"] + ' ' + metadata["Plot"]

metadata.head()
# Out:
#    MovieID     ImdbID                               Title  Rated  \
# 0        1  tt0114709                    Toy Story (1995)      G
# 1        2  tt0113497                      Jumanji (1995)     PG
# 2        3  tt0113228             Grumpier Old Men (1995)  PG-13
# 3        4  tt0114885            Waiting to Exhale (1995)      R
# 4        5  tt0113041  Father of the Bride Part II (1995)     PG
#
#                      Genre_imdb  \
# 0  Animation, Adventure, Comedy
# 1     Adventure, Comedy, Family
# 2               Comedy, Romance
# 3        Comedy, Drama, Romance
# 4       Comedy, Family, Romance
#
#                                                 Plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with his daugh...
#
#                                               Poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BZTk2Zm...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...
#
#                                         plot + genre
# 0  Animation, Adventure, Comedy A cowboy doll is ...
# 1  Adventure, Comedy, Family When two kids find a...
# 2  Comedy, Romance John and Max resolve to save t...
# 3  Comedy, Drama, Romance Based on Terry McMillan...
# 4  Comedy, Family, Romance George Banks must deal...

# %%
get_recommendations('Toy Story (1995)','plot + genre')
# Out:
#                                              Title  \
# 119            Amazing Panda Adventure, The (1995)
# 78                        Dunston Checks In (1996)
# 12                                    Balto (1995)
# 47                         Mighty Aphrodite (1995)
# 133                                   Congo (1995)
# 44                               Pocahontas (1995)
# 107  Chungking Express (Chung Hing sam lam) (1994)
# 88                                City Hall (1996)
# 120                 Basketball Diaries, The (1995)
# 109              NeverEnding Story III, The (1994)
#
#                       sim_score                       Genres  \
# 119  (119, 0.11013986953198283)     Adventure, Drama, Family
# 78    (78, 0.09900552455609749)    Adventure, Comedy, Family
# 12    (12, 0.08578522109002469)  Animation, Adventure, Drama
# 47    (47, 0.07999742483931899)     Comedy, Fantasy, Romance
# 133  (133, 0.07847372716370395)   Action, Adventure, Mystery
# 44    (44, 0.07809441979785128)  Animation, Adventure, Drama
# 107  (107, 0.07277938971871874)         Comedy, Crime, Drama
# 88    (88, 0.07219153132028869)        Crime, Drama, Mystery
# 120  (120, 0.07132701426112702)      Biography, Crime, Drama
# 109  (109, 0.07002001036307756)    Adventure, Comedy, Family
#
#                                                   Plot
# 119  A young American boy visiting China helps his ...
# 78   A young boy befriends a larcenous orangutan in...
# 12   An outcast Husky risks his life with other sle...
# 47   When he discovers his adopted son is a genius,...
# 133  When an expedition to the African Congo ends i...
# 44   An English soldier and the daughter of an Algo...
# 107  Two melancholy Hong Kong policemen fall in lov...
# 88   The accidental shooting of a boy in New York l...
# 120  A teenager finds his dreams of becoming a bask...
# 109  A young boy must restore order when a group of...

# %% [markdown]
# # Using MLP CLASSIFIER

# %%
from sklearn.neighbors import NearestNeighbors

# %%
samples = matrix_creation("plot + genre")

neigh = NearestNeighbors(n_neighbors=10, radius=0.5)

neigh.fit(samples)
# Out:
# NearestNeighbors(n_neighbors=10, radius=0.5)

# %%
test_array = neigh.kneighbors(samples[0,:], return_distance=True)

movie_ids_list = []
movie_title_list = []
movie_genre = []
distance_list = []
for i in test_array:
       
    for j in i:
        movie_ids_list.append(j)
        movie_title_list.append(metadata["Title"][j])
        movie_genre.append(metadata["Genre_imdb"][j])

# %%
test_array = neigh.kneighbors(samples[0,:], return_distance=True)

movie_ids_list = []
movie_distance = []
for i,j in test_array:
    for a in range(0,len(i[0])):
        print(i[0][a:a+1])
# Out:
# [0.]
# [1.33406157]
# [1.34238182]
# [1.35219435]
# [1.3564679]
# [1.35759071]
# [1.35787008]
# [1.3617787]
# [1.36221031]
# [1.36284481]
# [0]
# [119]
# [78]
# [12]
# [47]
# [133]
# [44]
# [107]
# [88]
# [120]

# %%
for i in test_array:
    print(i)
# Out:
# [  0 119  78  12  47 133  44 107  88 120]

# %%
test_df = pd.DataFrame({"movieId":movie_ids_list,"Title":movie_title_list, "Genre":movie_genre})
test_df
# Out:
#    movieId                                          Title  \
# 0        0                               Toy Story (1995)
# 1      119            Amazing Panda Adventure, The (1995)
# 2       78                       Dunston Checks In (1996)
# 3       12                                   Balto (1995)
# 4       47                        Mighty Aphrodite (1995)
# 5      133                                   Congo (1995)
# 6       44                              Pocahontas (1995)
# 7      107  Chungking Express (Chung Hing sam lam) (1994)
# 8       88                               City Hall (1996)
# 9      120                 Basketball Diaries, The (1995)
#
#                           Genre
# 0  Animation, Adventure, Comedy
# 1      Adventure, Drama, Family
# 2     Adventure, Comedy, Family
# 3   Animation, Adventure, Drama
# 4      Comedy, Fantasy, Romance
# 5    Action, Adventure, Mystery
# 6   Animation, Adventure, Drama
# 7          Comedy, Crime, Drama
# 8         Crime, Drama, Mystery
# 9       Biography, Crime, Drama

# %%
def NN_get_reccommendation(title,clusters,)

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(6, 4), random_state=1)
